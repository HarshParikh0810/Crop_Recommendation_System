# %%
# !pip install fastapi uvicorn joblib scikit-learn pandas pydantic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.4 MB/s eta 0:00:00
# ...

# %%
# print("Start")
# Out:
# Start

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from google.colab import files
# uploaded = files.upload()  # Manually upload required files
# Out:
#      <input type="file" id="files-e0b77b42-1acb-40d5-b60b-f93dc9d28f90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0b77b42-1acb-40d5-b60b-f93dc9d28f90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# import pandas as pd
# import joblib
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, MinMaxScaler
# from imblearn.over_sampling import SMOTE
# from xgboost import XGBClassifier
# from sklearn.metrics import accuracy_score, classification_report
# from fastapi import FastAPI
# from pydantic import BaseModel
# import uvicorn

# # Load dataset
# df = pd.read_csv("Crop_recommendation.csv")
#   # Check available columns
# df.rename(columns={'label': 'Crop'}, inplace=True)  # Adjust the key as needed
# print(df.columns)
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'Crop'], dtype='object')

# %%
# label_encoder = LabelEncoder()
# df['Crop'] = label_encoder.fit_transform(df['Crop'])

# # Features & target
# X = df.drop(columns=['Crop'])
# y = df['Crop']

# %%
# smote = SMOTE()
# X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
# # Scale features using MinMaxScaler
# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X_resampled)

# %%
# # Split data
# X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_resampled, test_size=0.2, random_state=42)

# %%
# # Train an optimized XGBoost model
# model = XGBClassifier(n_estimators=200, max_depth=5, learning_rate=0.1, random_state=42)
# model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# # Evaluate model
# y_pred = model.predict(X_test)
# accuracy = accuracy_score(y_test, y_pred)
# print(f"Model Accuracy: {accuracy * 100:.2f}%")
# print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# Model Accuracy: 98.64%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a57694f1826b> in <cell line: 0>()
#       3 accuracy = accuracy_score(y_test, y_pred)
#       4 print(f"Model Accuracy: {accuracy * 100:.2f}%")
# ----> 5 print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %%
# # Save model, encoder, and scaler
# joblib.dump(model, "crop_recommendation.pkl")
# joblib.dump(label_encoder, "label_encoder.pkl")
# joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# print(df["Crop"].value_counts())
# Out:
# Crop
# 20    100
# 11    100
# 3     100
# 9     100
# 18    100
# 13    100
# 14    100
# 2     100
# 10    100
# 19    100
# 1     100
# 12    100
# 7     100
# 21    100
# 15    100
# 0     100
# 16    100
# 17    100
# 4     100
# 6     100
# 8     100
# 5     100
# Name: count, dtype: int64

# %%
# print("Train Accuracy:", model.score(X_train, y_train))
# print("Test Accuracy:", model.score(X_test, y_test))
# Out:
# Train Accuracy: 1.0
# Test Accuracy: 0.9863636363636363

# %%
# import matplotlib.pyplot as plt

# feature_importance = model.feature_importances_
# plt.barh(X.columns, feature_importance)
# plt.xlabel("Feature Importance")
# plt.ylabel("Feature Name")
# plt.show()

# %%
# print("Before Scaling:\n", X.describe())
# print("After Scaling:\n", pd.DataFrame(X_scaled).describe())
# Out:
# Before Scaling:
#                   N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117
# ...

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# X_scaled = scaler.fit_transform(X)

# %%
# import matplotlib.pyplot as plt

# feature_importance = model.feature_importances_
# plt.barh(X.columns, feature_importance)
# plt.xlabel("Feature Importance")
# plt.ylabel("Feature Name")
# plt.title("Feature Importance in Random Forest")
# plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10,8))
# sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
# plt.show()

# %% [markdown]
# **Final Crop Model**

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

# 📌 Step 1: Load the dataset
df = pd.read_csv("Crop_recommendation.csv")  # Replace with actual file path

# 📌 Step 2: Check for missing values
print("Missing Values:\n", df.isnull().sum())

# If there are missing values, fill them (optional)
df.iloc[:, :-1] = df.iloc[:, :-1].apply(lambda x: x.fillna(x.mean()), axis=0)

# 📌 Step 3: Feature Selection (Defining X & y)
feature_columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
X = df[feature_columns]  # Features
y = df['label']  # Target (Crop Label)

# 📌 Step 4: Label Encoding for Target Variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  # Convert crop names to numerical values

# 📌 Step 5: Train-Test Split (80-20)
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, stratify=y_encoded, random_state=42
)

# 📌 Step 6: Feature Scaling using MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 📌 Step 7: Handle Class Imbalance using SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# 📌 Step 8: Train a Random Forest Classifier
model = RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_split=5, random_state=42)
model.fit(X_train_resampled, y_train_resampled)

# 📌 Step 9: Predictions
y_pred = model.predict(X_test_scaled)

# 📌 Step 10: Model Evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"🔹 Model Accuracy: {accuracy:.4f}")

# Classification Report
print("\n🔹 Classification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

# Confusion Matrix
plt.figure(figsize=(8,6))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# 📌 Step 11: Save the Model & Encoder for Future Use
import joblib

joblib.dump(model, "crop_prediction_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(label_encoder, "label_encoder.pkl")

print("✅ Model, Scaler, and Label Encoder Saved!")
# Out:
# Missing Values:
#  N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64
# 🔹 Model Accuracy: 0.9955
#
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        20
#       banana       1.00      1.00      1.00        20
#    blackgram       1.00      0.95      0.97        20
#     chickpea       1.00      1.00      1.00        20
#      coconut       1.00      1.00      1.00        20
#       coffee       1.00      1.00      1.00        20
#       cotton       1.00      1.00      1.00        20
#       grapes       1.00      1.00      1.00        20
#         jute       0.95      1.00      0.98        20
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       1.00      1.00      1.00        20
#        maize       0.95      1.00      0.98        20
# ...

# %%
# print(df.columns)
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')
